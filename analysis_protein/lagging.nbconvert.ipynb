# %%
import os
import numpy as np
import pandas as pd
import MDAnalysis as mda
from MDAnalysis.analysis.distances import distance_array

# %%
# Load trajectories (.xtc) and topology file (.tpr)
trajfiles2 = ("/scratch/gent/vo/000/gvo00003/vsc48847/BDN_bound/gromacs/step7_production_rep1_f.xtc", 
             "/scratch/gent/vo/000/gvo00003/vsc48847/BDN_bound/gromacs/step7_production_rep2_f.xtc",
             "/scratch/gent/vo/000/gvo00003/vsc48847/BDN_bound/gromacs/step7_production_rep3_f.xtc",
            )
topfile2 = ("/scratch/gent/vo/000/gvo00003/vsc48847/BDN_bound/gromacs/step7_production_rep1.tpr")
trajfiles3 = ("/scratch/gent/vo/000/gvo00003/vsc48847/BDQ_bound/gromacs/step7_production_rep1_f.xtc", 
             "/scratch/gent/vo/000/gvo00003/vsc48847/BDQ_bound/gromacs/step7_production_rep2_f.xtc",
             "/scratch/gent/vo/000/gvo00003/vsc48847/BDQ_bound/gromacs/step7_production_rep3_f.xtc",
            )
topfile3 = ("/scratch/gent/vo/000/gvo00003/vsc48847/BDQ_bound/gromacs/step7_production_rep1.tpr")
bdn1 = mda.Universe(topfile2, trajfiles2[0])
bdn2 = mda.Universe(topfile2, trajfiles2[1])
bdn3 = mda.Universe(topfile2, trajfiles2[2])
bdn = mda.Universe(topfile2, trajfiles2)

bdq1 = mda.Universe(topfile3, trajfiles3[0])
bdq2 = mda.Universe(topfile3, trajfiles3[1])
bdq3 = mda.Universe(topfile3, trajfiles3[2])
bdq = mda.Universe(topfile3, trajfiles3)

# %%
import numpy as np
from MDAnalysis.analysis.distances import distance_array

def min_distance_timeseries(u, protein_resid, ligand_resid):

    protein = u.select_atoms(
        f"protein and resid {protein_resid} and not name H*"
    )

    ligand = u.select_atoms(
        f"resid {ligand_resid} and not name H*"
    )

    distances = []

    for ts in u.trajectory:

        d = distance_array(
            protein.positions,
            ligand.positions,
            box=u.dimensions
        )

        distances.append(np.min(d))

    return np.array(distances)

# %%
import os
import pandas as pd


def run_distance_analysis(
    systems,
    sites,
    outdir
):

    os.makedirs(outdir, exist_ok=True)

    for system_name, replicas in systems.items():

        system_dir = os.path.join(outdir, system_name)
        os.makedirs(system_dir, exist_ok=True)

        for site_name, (protein_resid, ligand_resid) in sites.items():

            print(
                f"{system_name} | {site_name}: "
                f"prot {protein_resid} ↔ lig {ligand_resid}"
            )

            site_dir = os.path.join(system_dir, site_name)
            os.makedirs(site_dir, exist_ok=True)

            all_replicas = []

            for rep_idx, u in enumerate(replicas, start=1):

                dist = min_distance_timeseries(
                    u,
                    protein_resid,
                    ligand_resid
                )

                df = pd.DataFrame({

                    "System": system_name,
                    "ProteinResid": protein_resid,
                    "LigandResid": ligand_resid,
                    "Replica": rep_idx,
                    "Frame": range(len(dist)),
                    "MinDistance": dist

                })

                all_replicas.append(df)

            combined = pd.concat(all_replicas, ignore_index=True)

            outpath = os.path.join(
                site_dir,
                "min_distance_timeseries.csv"
            )

            combined.to_csv(outpath, index=False)

            print(f"Saved -> {outpath}")

# %%
systems = {
    "BDN": [bdn1, bdn2, bdn3],
    "BDQ": [bdq1, bdq2, bdq3]
}

glu61_sites = {
    "ala": [299, 1064],
    "tyr": [301, 1064],
    "phe": [302, 1064],
    "leu": [305, 1064],
    "asp": [265, 1064],
    "ala1_h2": [380, 1064],
    "ala2_h2": [381, 1064]
}

# %%
run_distance_analysis(
    systems=systems,
    sites=glu61_sites,
    outdir="/scratch/gent/vo/000/gvo00003/vsc48847/distance_analysis/lagging"
)
# Out:
# BDN | ala: prot 299 ↔ lig 1064
# Saved -> /scratch/gent/vo/000/gvo00003/vsc48847/distance_analysis/lagging/BDN/ala/min_distance_timeseries.csv
# BDN | tyr: prot 301 ↔ lig 1064
# Saved -> /scratch/gent/vo/000/gvo00003/vsc48847/distance_analysis/lagging/BDN/tyr/min_distance_timeseries.csv
# BDN | phe: prot 302 ↔ lig 1064
# Saved -> /scratch/gent/vo/000/gvo00003/vsc48847/distance_analysis/lagging/BDN/phe/min_distance_timeseries.csv
# BDN | leu: prot 305 ↔ lig 1064
# Saved -> /scratch/gent/vo/000/gvo00003/vsc48847/distance_analysis/lagging/BDN/leu/min_distance_timeseries.csv
# BDN | asp: prot 265 ↔ lig 1064
# Saved -> /scratch/gent/vo/000/gvo00003/vsc48847/distance_analysis/lagging/BDN/asp/min_distance_timeseries.csv
# BDN | ala1_h2: prot 380 ↔ lig 1064
# Saved -> /scratch/gent/vo/000/gvo00003/vsc48847/distance_analysis/lagging/BDN/ala1_h2/min_distance_timeseries.csv
# BDN | ala2_h2: prot 381 ↔ lig 1064
# Saved -> /scratch/gent/vo/000/gvo00003/vsc48847/distance_analysis/lagging/BDN/ala2_h2/min_distance_timeseries.csv
# BDQ | ala: prot 299 ↔ lig 1064
# Saved -> /scratch/gent/vo/000/gvo00003/vsc48847/distance_analysis/lagging/BDQ/ala/min_distance_timeseries.csv
# BDQ | tyr: prot 301 ↔ lig 1064
# Saved -> /scratch/gent/vo/000/gvo00003/vsc48847/distance_analysis/lagging/BDQ/tyr/min_distance_timeseries.csv
# BDQ | phe: prot 302 ↔ lig 1064
# Saved -> /scratch/gent/vo/000/gvo00003/vsc48847/distance_analysis/lagging/BDQ/phe/min_distance_timeseries.csv
# BDQ | leu: prot 305 ↔ lig 1064
# Saved -> /scratch/gent/vo/000/gvo00003/vsc48847/distance_analysis/lagging/BDQ/leu/min_distance_timeseries.csv
# BDQ | asp: prot 265 ↔ lig 1064
# Saved -> /scratch/gent/vo/000/gvo00003/vsc48847/distance_analysis/lagging/BDQ/asp/min_distance_timeseries.csv
# BDQ | ala1_h2: prot 380 ↔ lig 1064
# Saved -> /scratch/gent/vo/000/gvo00003/vsc48847/distance_analysis/lagging/BDQ/ala1_h2/min_distance_timeseries.csv
# BDQ | ala2_h2: prot 381 ↔ lig 1064
# Saved -> /scratch/gent/vo/000/gvo00003/vsc48847/distance_analysis/lagging/BDQ/ala2_h2/min_distance_timeseries.csv
